# %%
from torchvision import models

# %%
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
# ...

# %% [markdown]
# ## Using AlexNet

# %%
alexnet = models.AlexNet()

# %% [markdown]
# ## ResNet
#
# Downloading the weights of resnet101 trained on ImageNet dataset, with 1.2 million images and 1000 categories

# %%
resnet = models.resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...

# %%
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
from torchvision import transforms
preprocess = transforms.Compose([
                                 transforms.Resize(256),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(
                                     mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]
                                 )
])

# %%
from PIL import Image
img = Image.open("/content/drive/MyDrive/PyTorch/Deep Learning with PyTorch Book/322868_1100-800x825.jpg")

# %%
img_t = preprocess(img)
img_t
# Out:
# tensor([[[ 1.7352,  1.7352,  1.7352,  ...,  1.8893,  1.8893,  1.9064],
#          [ 1.7352,  1.7352,  1.7352,  ...,  1.8722,  1.8893,  1.9064],
#          [ 1.7352,  1.7352,  1.7352,  ...,  1.8722,  1.8893,  1.9064],
#          ...,
#          [ 1.5125,  1.5125,  1.5125,  ...,  0.4337,  0.4679,  0.5364],
#          [ 1.5125,  1.5125,  1.5125,  ...,  0.4851,  0.5193,  0.5536],
#          [ 1.5125,  1.5125,  1.5125,  ...,  0.5022,  0.5022,  0.5193]],
#
#         [[ 1.6232,  1.6232,  1.6232,  ...,  1.9209,  1.9209,  1.9384],
#          [ 1.6232,  1.6232,  1.6232,  ...,  1.9034,  1.9209,  1.9384],
#          [ 1.6232,  1.6232,  1.6232,  ...,  1.9034,  1.9209,  1.9384],
#          ...,
#          [ 1.2906,  1.2906,  1.2906,  ..., -0.4426, -0.4076, -0.3375],
#          [ 1.2906,  1.2906,  1.2906,  ..., -0.3901, -0.3550, -0.3200],
#          [ 1.2906,  1.2906,  1.2906,  ..., -0.3725, -0.3725, -0.3550]],
#
#         [[ 1.6117,  1.6117,  1.6117,  ...,  2.0997,  2.0997,  2.1171],
# ...

# %%
import torch
batch_t = torch.unsqueeze(img_t, 0)

# %%
resnet.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
out = resnet(batch_t)
out
# Out:
# tensor([[-9.2496e-01, -5.7377e-01, -2.6097e+00, -3.7739e+00, -4.2376e+00,
#          -1.2763e+00, -3.4685e+00, -9.3768e-01,  1.3514e-01, -3.3158e+00,
#          -1.4588e+00, -3.0615e-01, -1.0315e+00, -3.5145e+00, -1.2890e+00,
#          -2.1665e+00, -6.7158e-01, -5.1186e-01, -2.1740e+00, -1.9090e+00,
#          -3.7580e+00, -1.3751e+00, -8.4361e-01,  4.8366e-01, -1.9150e+00,
#          -1.0224e+00, -2.0399e+00, -6.1088e-01, -6.7597e-01, -1.6796e+00,
#          -1.2847e+00, -1.9290e+00, -1.8426e+00, -2.7653e+00, -8.3348e-01,
#          -2.4823e+00, -9.7596e-01, -2.0106e+00,  2.2798e-01,  1.1409e+00,
#           2.4664e-01,  5.1003e-01,  2.6050e+00,  2.8664e-01,  1.2547e-02,
#          -6.3755e-01,  1.8424e+00,  4.9388e-01, -1.9183e+00,  1.2663e-02,
#          -2.2369e+00, -4.3870e-01, -1.2887e+00, -2.3813e+00, -2.4108e+00,
#          -1.1051e+00, -7.4792e-01, -6.0734e-01, -2.9701e+00,  9.0470e-01,
#           2.6420e-01, -2.0039e+00, -2.0630e-01, -2.3002e+00, -2.7149e-01,
# ...

# %%
with open("/content/drive/MyDrive/PyTorch/Deep Learning with PyTorch Book/image_net_classes.txt") as f:
    labels = [line.strip() for line in f.readlines()]

# %%
_, index = torch.max(out, 1)

# %%
percentage = torch.nn.functional.softmax(out, dim=1)[0] * 100
labels[index[0]], percentage[index[0]].item()
# Out:
# ('golden retriever', 58.47340393066406)

# %%
_, indices = torch.sort(out, descending=True)
[(labels[idx], percentage[idx].item()) for idx in indices[0][:5]]
# Out:
# [('golden retriever', 58.47340393066406),
#  ('Brittany spaniel', 21.132431030273438),
#  ('Chesapeake Bay retriever', 5.388154983520508),
#  ('tennis ball', 4.988626003265381),
#  ('flat-coated retriever', 4.141221523284912)]
